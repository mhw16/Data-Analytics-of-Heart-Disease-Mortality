# %%
#Importing the necessary python packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Loading the file 
data = pd.read_csv('HeartMortality.csv')
print(data)
# Out:
#        Year LocationAbbr                     LocationDesc GeographicLevel  \
# 0      2014           AK                   Aleutians East          County
# 1      2014           AK                   Aleutians West          County
# 2      2014           AK                        Anchorage          County
# 3      2014           AK                           Bethel          County
# 4      2014           AK                      Bristol Bay          County
# 5      2014           AK                           Denali          County
# 6      2014           AK                       Dillingham          County
# 7      2014           AK             Fairbanks North Star          County
# 8      2014           AK                           Haines          County
# 9      2014           AK                           Juneau          County
# 10     2014           AK                  Kenai Peninsula          County
# 11     2014           AK                Ketchikan Gateway          County
# ...

# %%
#Printing the statistical summary of 'HeartMortality'
data.describe()
# Out:
#           Year    Data_Value    LocationID
# count  59076.0  32149.000000  59076.000000
# mean    2014.0    349.306775  30946.267215
# std        0.0    140.549773  16728.893538
# min     2014.0      6.000000      0.000000
# 25%     2014.0    253.300000  18137.000000
# 50%     2014.0    340.000000  29208.000000
# 75%     2014.0    433.800000  46091.000000
# max     2014.0   3000.900000  78030.000000

# %%
#Identifying null values
data.isnull()
# Out:
#         Year  LocationAbbr  LocationDesc  GeographicLevel  DataSource  Class  \
# 0      False         False         False            False       False  False
# 1      False         False         False            False       False  False
# 2      False         False         False            False       False  False
# 3      False         False         False            False       False  False
# 4      False         False         False            False       False  False
# 5      False         False         False            False       False  False
# 6      False         False         False            False       False  False
# 7      False         False         False            False       False  False
# 8      False         False         False            False       False  False
# 9      False         False         False            False       False  False
# 10     False         False         False            False       False  False
# ...

# %%
#Cleaning two of the columns of NaN values, since they are footnotes the values do not necessarily matter
cleaned=data.fillna({'Data_Value_Footnote_Symbol':0,'Data_Value_Footnote':0})
print(cleaned)
# Out:
#        Year LocationAbbr                     LocationDesc GeographicLevel  \
# 0      2014           AK                   Aleutians East          County
# 1      2014           AK                   Aleutians West          County
# 2      2014           AK                        Anchorage          County
# 3      2014           AK                           Bethel          County
# 4      2014           AK                      Bristol Bay          County
# 5      2014           AK                           Denali          County
# 6      2014           AK                       Dillingham          County
# 7      2014           AK             Fairbanks North Star          County
# 8      2014           AK                           Haines          County
# 9      2014           AK                           Juneau          County
# 10     2014           AK                  Kenai Peninsula          County
# 11     2014           AK                Ketchikan Gateway          County
# ...

# %%
#Cleaning the rows of values that do not have a number per 100,000.
#I decided to drop the rows because it would be wrong to input falsified statistics.
#This instance is not permanant.
cleaned.dropna()
# Out:
#        Year LocationAbbr          LocationDesc GeographicLevel DataSource  \
# 0      2014           AK        Aleutians East          County       NVSS
# 1      2014           AK        Aleutians West          County       NVSS
# 2      2014           AK             Anchorage          County       NVSS
# 3      2014           AK                Bethel          County       NVSS
# 5      2014           AK                Denali          County       NVSS
# 6      2014           AK            Dillingham          County       NVSS
# 7      2014           AK  Fairbanks North Star          County       NVSS
# 8      2014           AK                Haines          County       NVSS
# 9      2014           AK                Juneau          County       NVSS
# 10     2014           AK       Kenai Peninsula          County       NVSS
# 11     2014           AK     Ketchikan Gateway          County       NVSS
# 12     2014           AK         Kodiak Island          County       NVSS
# ...

# %%
#Checking the missing values
cleaned.isnull()
# Out:
#         Year  LocationAbbr  LocationDesc  GeographicLevel  DataSource  Class  \
# 0      False         False         False            False       False  False
# 1      False         False         False            False       False  False
# 2      False         False         False            False       False  False
# 3      False         False         False            False       False  False
# 4      False         False         False            False       False  False
# 5      False         False         False            False       False  False
# 6      False         False         False            False       False  False
# 7      False         False         False            False       False  False
# 8      False         False         False            False       False  False
# 9      False         False         False            False       False  False
# 10     False         False         False            False       False  False
# ...

# %%
#Grouping important aspects of data (Location, Gender, and ethnicity)
state = cleaned.groupby('LocationAbbr').mean()
print(state)
gender = cleaned.groupby('Stratification1').mean()
print(gender)
race = cleaned.groupby('Stratification2').mean()
print(race)
date = cleaned.groupby('Year').mean()
print(date)
# Out:
#                 Year  Data_Value    LocationID
# LocationAbbr
# AK            2014.0  318.396517   2077.285714
# AL            2014.0  452.940996   1051.323529
# AR            2014.0  447.272996   5008.289474
# AS            2014.0  343.533333  30030.000000
# AZ            2014.0  272.962357   3763.250000
# CA            2014.0  298.068489   5955.423729
# CO            2014.0  247.797399   7938.323077
# CT            2014.0  255.655882   8008.111111
# DC            2014.0  306.178571   5506.000000
# DE            2014.0  270.705172   7504.750000
# FL            2014.0  286.450326  11890.617647
# GA            2014.0  380.160799  13079.312500
# GU            2014.0  529.800000  33038.000000
# HI            2014.0  300.981707  12506.666667
# IA            2014.0  329.146016  18908.200000
# ID            2014.0  278.923204  15687.822222
# IL            2014.0  343.175380  16936.126214
# IN            2014.0  354.644851  17897.655914
# KS            2014.0  339.465344  19915.518868
# ...

# %%
#Initial Graphical Summary
import matplotlib.pyplot as plt
# %matplotlib inline

gender['Data_Value'].plot.bar()

# %%
race['Data_Value'].plot.bar()

# %%
import seaborn as sns; sns.set(color_codes=True)
sns.kdeplot(cleaned.Data_Value[cleaned.Stratification1 =='Male'], label ='men', shade = True)
sns.kdeplot(cleaned.Data_Value[cleaned.Stratification1 =='Female'], label ='women', shade = True)
plt.xlabel('Heart Disease Mortality')
# Out:
# C:\Users\Michael\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:454: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X>clip[0], X<clip[1])] # won't work for two columns.
# C:\Users\Michael\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:454: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X>clip[0], X<clip[1])] # won't work for two columns.
# Text(0.5,0,'Heart Disease Mortality')

# %%
x = cleaned['Data_Value']

y = cleaned['Stratification1']

#plot
plt.scatter(x,y)


plt.title('Scatter Plot')
plt.xlabel('Heart Disease Mortality')
plt.ylabel('Gender')
# Out:
# Text(0,0.5,'Gender')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (20,3)
state['Data_Value'].plot.bar()
